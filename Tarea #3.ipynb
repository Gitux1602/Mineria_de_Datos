# %%
import pandas as pd # Importamos la libreria pandas

# %%
df = pd.read_csv('https://www.football-data.co.uk/new/ARG.csv') # Leemos el archivo csv

# %%
df['Date'] = pd.to_datetime(df['Date']) # Cambiamos la columna 'Date' en un formato de fecha y hora adecuado que Pandas pueda reconocer
# Out:
# C:\Users\Gilberto\AppData\Local\Temp\ipykernel_22268\2305757915.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date']) # Cambiamos la columna 'Date' en un formato de fecha y hora adecuado que Pandas pueda reconocer

# %%
boca_river_matches = df[(df['Home'] == 'Boca Juniors') & (df['Away'] == 'River Plate') | (df['Home'] == 'River Plate') & (df['Away'] == 'Boca Juniors')]
# Guarda todos los partidos entre Boca Juniors y River Plate //Los equipos mas grandes de Argentina avalado por sus títulos

# %%
boca_river_matches[boca_river_matches['Date'].dt.year >= 2015]
# Out:
#         Country                       League     Season       Date   Time  \
# 1114  Argentina            Liga Profesional        2015 2015-03-05  22:15
# 1308  Argentina            Liga Profesional        2015 2015-09-13  22:15
# 1503  Argentina            Liga Profesional        2016 2016-06-03  20:00
# 1597  Argentina            Liga Profesional        2016 2016-04-24  20:15
# 1852  Argentina            Liga Profesional   2016/2017 2016-11-12  20:00
# 2015  Argentina            Liga Profesional   2016/2017 2017-05-14  21:00
# 2222  Argentina             Liga Profesional  2017/2018 2017-05-11  21:05
# 2565  Argentina             Liga Profesional  2018/2019 2018-09-23  21:45
# 2874  Argentina             Liga Profesional  2019/2020 2019-01-09  21:00
# 3201  Argentina  Copa de la Liga Profesional       2020 2021-03-01  00:30
# 3285  Argentina  Copa de la Liga Profesional       2021 2021-03-14  21:00
# 3398  Argentina  Copa de la Liga Profesional       2021 2021-05-16  21:30
# ...

# %%
# Filtra los partidos en los que River Plate ganó de visita
river_wins_as_visitor = df[(df['Away'] == 'River Plate') & (df['Res'] == 'A')]

# Filtra los partidos en los que Boca Juniors ganó en casa (de local)
boca_wins_at_home = df[(df['Home'] == 'Boca Juniors') & (df['Res'] == 'H')]

# %%
# Cuenta las victorias de River Plate de visita y de Boca Juniors en casa
river_wins_count = len(river_wins_as_visitor)
boca_wins_count = len(boca_wins_at_home)

# %%
# Gráfico de barras para las victorias de River Plate de visita y de Boca Juniors en casa
plt.figure(figsize=(8, 6))
plt.bar(['River Plate (Visita)', 'Boca Juniors (Local)'], [river_wins_count, boca_wins_count], color=['Red', 'Blue'])
plt.xlabel('Equipo')
plt.ylabel('Cantidad de Victorias')
plt.title('Victorias de River Plate y Boca Juniors')
plt.show()

print(f'River Plate ha ganado de visita {river_wins_count} veces.')
print(f'Boca Juniors ha ganado en casa (de local) {boca_wins_count} veces.')
# Out:
# River Plate ha ganado de visita 88 veces.
# Boca Juniors ha ganado en casa (de local) 115 veces.

# %%
# Filtra los partidos en los que Boca Juniors ganó de visita
boca_wins_at_home = df[(df['Away'] == 'Boca Juniors') & (df['Res'] == 'A')]
# Filtra los partidos en los que River Plate ganó en casa (de local)
river_wins_as_visitor = df[(df['Home'] == 'River Plate') & (df['Res'] == 'H')]

# %%
# Cuenta las victorias de River Plate de visita y de Boca Juniors en casa
river_wins_count = len(river_wins_as_visitor)
boca_wins_count = len(boca_wins_at_home)

# %%
# Gráfico de barras para las victorias de River Plate de visita y de Boca Juniors en casa
plt.figure(figsize=(8, 6))
plt.bar(['River Plate (Local)', 'Boca Juniors (Visita)'], [river_wins_count, boca_wins_count], color=['Red', 'Blue'])
plt.xlabel('Equipo')
plt.ylabel('Cantidad de Victorias')
plt.title('Victorias de River Plate y Boca Juniors')
plt.show()

print(f'Boca Juniors ha ganado de visita {boca_wins_count} veces.')
print(f'River Plate ha ganado en casa (de local) {river_wins_count} veces.')
# Out:
# Boca Juniors ha ganado de visita 76 veces.
# River Plate ha ganado en casa (de local) 105 veces.

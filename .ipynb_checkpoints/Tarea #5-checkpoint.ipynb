# %%
import pandas as pd # Importamos la libreria pandas
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('https://www.football-data.co.uk/new/ARG.csv') # Leemos el archivo csv

# %%
boca_river_matches = df[(df['Home'] == 'Boca Juniors') & (df['Away'] == 'River Plate') | (df['Home'] == 'River Plate') & (df['Away'] == 'Boca Juniors')]
# Guarda todos los partidos entre Boca Juniors y River Plate //Los equipos mas grandes de Argentina avalado por sus títulos

# %%
boca_river_matches
# Out:
#         Country                       League     Season        Date   Time  \
# 115   Argentina            Liga Profesional   2012/2013  28/10/2012  18:30
# 305   Argentina            Liga Profesional   2012/2013  05/05/2013  20:30
# 475   Argentina            Liga Profesional   2013/2014  06/10/2013  22:15
# 669   Argentina            Liga Profesional   2013/2014  30/03/2014  22:15
# 859   Argentina            Liga Profesional        2014  05/10/2014  21:15
# 1114  Argentina            Liga Profesional        2015  03/05/2015  22:15
# 1308  Argentina            Liga Profesional        2015  13/09/2015  22:15
# 1503  Argentina            Liga Profesional        2016  06/03/2016  20:00
# 1597  Argentina            Liga Profesional        2016  24/04/2016  20:15
# 1852  Argentina            Liga Profesional   2016/2017  11/12/2016  20:00
# 2015  Argentina            Liga Profesional   2016/2017  14/05/2017  21:00
# ...

# %%
#P5
# Definimos los grupos para el ANOVA.
grupo_local_boca = goles_boca_river[(goles_boca_river['Home'] == 'Boca Juniors')]['HG']
grupo_local_river = goles_boca_river[(goles_boca_river['Home'] == 'River Plate')]['HG']
grupo_visitante_boca = goles_boca_river[(goles_boca_river['Away'] == 'Boca Juniors')]['AG']
grupo_visitante_river = goles_boca_river[(goles_boca_river['Away'] == 'River Plate')]['AG']

# Realizamos el ANOVA para comparar los grupos.
f_statistic, p_value = stats.f_oneway(grupo_local_boca, grupo_local_river, grupo_visitante_boca, grupo_visitante_river)

print("Estadística F:", f_statistic)
print("Valor p:", p_value)

if p_value < 0.05:
    print("Hay diferencias significativas entre los grupos.")
else:
    print("No hay diferencias significativas entre los grupos.")
# Out:
# Estadística F: 0.566666666666667
# Valor p: 0.640186451325112
# No hay diferencias significativas entre los grupos.
